# %% [markdown]
# # Etherscan csv Reader

# %%
import numpy as np
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt

# %%
file_path = "export-0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045.csv"

# %%
df = pd.read_csv(file_path, index_col=False)

# %%
display(df)
# Out:
#                                                 Txhash   Blockno  \
# 0    0xd62053c4465251ceb75624d7447bda963863901cc316...  14116900
# 1    0xfd2968d66b6a071170b5e787997e711a9f5dd2f49a53...  14116900
# 2    0x2802dd45df894e1ce9aa61adcbbbae80f3988a977da9...  14116901
# 3    0xbb68b286b3600a2adfec9ddf899acfe5ec725dc84b33...  14135315
# 4    0x9503d3cd397c805a63570f5f4640d26203a9b8efea57...  14159311
# ..                                                 ...       ...
# 533  0x34d1dd91a8ef4db8b5ec3a0e4bcbe979b6baa577d9d3...  16492380
# 534  0x5ce02f6e35417bcb4ef813c47d246d625c2edc8e4bc4...  16492605
# 535  0xe6b90c53973f42958b460a93c54b007b358a9bc42231...  16496930
# 536  0x2a6d0295fe9ecc34e51d68ddbb3306021d0a511b35ad...  16510003
# 537  0x81e7d84ed2fcf3dab982b315d3ed1ac4b2b08da81e53...  16513090
#
#      UnixTimestamp             DateTime  \
# 0       1643675365  2022-02-01 00:29:25
# 1       1643675365  2022-02-01 00:29:25
# 2       1643675394  2022-02-01 00:29:54
# ...

# %%
df.dtypes
# Out:
# Txhash                          object
# Blockno                          int64
# UnixTimestamp                    int64
# DateTime                        object
# From                            object
# To                              object
# ContractAddress                float64
# Value_IN(ETH)                  float64
# Value_OUT(ETH)                 float64
# CurrentValue @ $1612.45/Eth    float64
# TxnFee(ETH)                    float64
# TxnFee(USD)                    float64
# Historical $Price/Eth          float64
# Status                          object
# ErrCode                         object
# Method                          object
# dtype: object

# %%
df.describe()
# Out:
#             Blockno  UnixTimestamp  ContractAddress  Value_IN(ETH)  \
# count  5.380000e+02   5.380000e+02              0.0     538.000000
# mean   1.543531e+07   1.661379e+09              NaN       0.000527
# std    6.924455e+05   9.105197e+06              NaN       0.002349
# min    1.411690e+07   1.643675e+09              NaN       0.000000
# 25%    1.482225e+07   1.653206e+09              NaN       0.000000
# 50%    1.551978e+07   1.662970e+09              NaN       0.000000
# 75%    1.600367e+07   1.668856e+09              NaN       0.000010
# max    1.651309e+07   1.675003e+09              NaN       0.027000
#
#        Value_OUT(ETH)  CurrentValue @ $1612.45/Eth  TxnFee(ETH)  TxnFee(USD)  \
# count      538.000000                 5.380000e+02   538.000000   538.000000
# mean        22.035189                 3.553149e+04     0.002645     4.265626
# std        104.048715                 1.677732e+05     0.006511    10.499079
# ...

# %%
print(f" Data from {min(df['DateTime'])} to {max(df['DateTime'])}")
# Out:
#  Data from 2022-02-01 00:29:25 to 2023-01-29 14:31:47

# %% [markdown]
# ## Plotting Data

# %%
df.columns
# Out:
# Index(['Txhash', 'Blockno', 'UnixTimestamp', 'DateTime', 'From', 'To',
#        'ContractAddress', 'Value_IN(ETH)', 'Value_OUT(ETH)',
#        'CurrentValue @ $1612.45/Eth', 'TxnFee(ETH)', 'TxnFee(USD)',
#        'Historical $Price/Eth', 'Status', 'ErrCode', 'Method'],
#       dtype='object')

# %%
ethprice = df['Historical $Price/Eth']
Date = df['DateTime']

# %%
df1 = pd.concat([ethprice, Date], axis=1).dropna()
df1
# Out:
#      Historical $Price/Eth             DateTime
# 0                  2790.15  2022-02-01 00:29:25
# 1                  2790.15  2022-02-01 00:29:25
# 2                  2790.15  2022-02-01 00:29:54
# 3                  2697.18  2022-02-03 20:59:25
# 4                  3141.38  2022-02-07 13:56:07
# ..                     ...                  ...
# 531                1601.35  2023-01-26 08:33:23
# 532                1601.35  2023-01-26 15:15:11
# 533                1601.35  2023-01-26 17:07:35
# 534                1601.35  2023-01-26 17:52:47
# 535                1597.86  2023-01-27 08:22:47
#
# [536 rows x 2 columns]

# %%
df.plot(x="DateTime",
              y="Historical $Price/Eth", 
              title="ETH price on txns")
# Out:
# <AxesSubplot: title={'center': 'ETH price on txns'}, xlabel='DateTime'>
