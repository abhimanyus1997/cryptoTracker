# %% [markdown]
# # webscrape etherscan

# %% [markdown]
# ## Import Libaries

# %%
# !pip install requests beautifulsoup4
# Out:
# ...
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# ...
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Getting Request

# %%
account = input()

if account.strip() == "":  # ✅ prevents empty input (including whitespace characters)
    account = "0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045"

print(account)
# Out:
# 0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045

# %%
import requests

# Making a GET request
account_url = "https://etherscan.io/address/"+account

# Added Useragent to bypass you are not bot
r = requests.get(account_url,
                 headers={'User-Agent': "Mozilla/5.0 (Windows NT 10.0 ; Win64 ;x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"}
    )

# check status code for response received
# success code - 200
print(r)

# print content of request
#print(r.content)
# Out:
# <Response [200]>

# %% [markdown]
# ## Parsing HTML using BS

# %%
# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    vitalik.eth | Address 0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045 | Etherscan
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="etherscan.io" name="author"/>
#   <meta content="The Address 0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045 page allows users to view transactions, balances, token holdings and transfers of ERC-20, ERC-721 and ERC-1155 (NFT) tokens, and analytics." name="Description"/>
#   <meta content="ethereum, explorer, ether, search, blockchain, crypto, currency" name="keywords"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="vitalik.eth | Address 0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045 | Etherscan" property="og:title"/>
# ...

# %%
# Finding Ether Balance & usd bal
balance = soup.find_all('div', class_='col-md-8')
print(balance[0].text)  # ETH tokens
print(balance[1].text)  # Current Value
# Out:
# 7,566.673381887160221433 Ether
# $12,351,534.96 (@ $1,632.36/ETH)
